# %%
import matplotlib.pyplot as plt
plt.plot([0, 1], [0, 1])
# plt.ylabel(r"$x$")
# plt.rcParams['text.usetex'] = True
plt.show()
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# File ~/miniconda3/envs/fv3net/lib/python3.8/site-packages/matplotlib/texmanager.py:304, in TexManager._run_checked_subprocess(self, command, tex)
#     303 try:
# --> 304     report = subprocess.check_output(command,
#     305                                      cwd=self.texcache,
#     306                                      stderr=subprocess.STDOUT)
#     307 except FileNotFoundError as exc:
#
# File ~/miniconda3/envs/fv3net/lib/python3.8/subprocess.py:415, in check_output(timeout, *popenargs, **kwargs)
#     413     kwargs['input'] = empty
# --> 415 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     416            **kwargs).stdout
#
# File ~/miniconda3/envs/fv3net/lib/python3.8/subprocess.py:516, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     515     if check and retcode:
# ...

# %%
import sys
# !{sys.executable} -m pip install latex
